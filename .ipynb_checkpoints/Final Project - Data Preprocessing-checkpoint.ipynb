# %% [markdown]
# # NYS Residential Homes Energy Efficiency Projects

# %% [markdown]
# > The Green Jobs - Green New York Program provides New Yorkers with access to energy assesments, installation services, low interest financing, and pathway to training for various green-collar careers

# %% [markdown]
# ## Columns Explanation:
#
# - Reporting Period : The time period covered by the data set
# - Home Performance Project ID : Unique identifier for project
# - Home Performance Site ID	: Unique site identifier for location of the project
# - Project County : Name of county for project location
# - Project City : Name of city for project location
# - Project Zip : Name of zip code for project location
# - Gas Utility : Name of gas utility for project location. If blank, then utility was not reported, or project location is not served by a gas utility
# - Electric Utility	: Name of electric utility for project location
# - Project Completion Date : Date final project completion paperwork was reviewed and approved by Program.
# - Customer Type	: Indicates if the homeowner received market rate incentives or the assisted subsidy for households with income up to 80% of the State or median county income, whichever is higher
# - Low-Rise or Home Performance Indicator : Indicates whether project was part of a low-rise community initiative or a single-family home performance project. Low-rise projects are not eligible for residential loan products, or free or reduced cost audits. Each unit served on a low-rise project is treated as an individual project
# - Total Project Cost : Cost of project in US dollars (USD)
# - Total Incentives : Total Incentives Numeric Amount of homeowner incentive (USD). Zero dollars represent either projects receiving only financing, or Market Rate projects that did not receive an incentive, but still participated in the program to take advantage of working with participating contractors and Quality Assurance benefits
# - Type of Program Financing	: Indicates type of Program financing a project received, including current financing options of GJGNY On-Bill Recovery Loan, GJGNY Smart Energy Loan, and legacy financing options (Energy Smart Loan Fund (ESMART) and Home Performance with ENERGY STAR Financing (ESTAR)).
# - Amount Financed Through Program : Project loan amount (USD). If blank, then project was not financed through the GJGNY Smart Energy Loan Program, GJGNY On-Bill Recovery Loan or other legacy Program financing option.
# - Pre-Retrofit Home Heating Fuel Type	: Indicates the pre-retrofit primary heating fuel type
# - Year Home Built	: Home construction date.
# - Size of Home	: Square footage of home.
# - Volume of Home : Approximate volume of conditioned space of the home.
# - Number of Units : Number of units served by the Program .
# - Measure Type	: Measure classification describing primary project improvement.
# - Estimated Annual kWh Savings	: Annual post-retrofit modeled electric savings estimate in kWh. Negative numbers represent projects with post-retrofit increase in electric consumption, typically from fuel conversions or ancillary savings
# - Estimated Annual MMBtu Savings : Annual post-retrofit modeled MMBtu savings based on primary fuel type. Negative numbers represent projects with post-retrofit increase in MMBtu consumption, typically from fuel conversions or ancillary savings
# - First Year Energy Savings Estimate : Estimated modeled post-retrofit first year dollar savings (USD). Negative numbers represent projects with estimated post-retrofit first year dollar expenses, typically occurring when non-energy work was completed such as health and safety improvements, or when work was done in conjunction with another, net positive energy savings project
# - Homeowner Received Green Jobs-Green NY Free/Reduced Cost Audit (Y/N)	: Indicator if the homeowner received a Free/Reduced Cost Green Jobs Green-NY audit prior to retrofit work
# - Location	: Municipal location based on supplied address location.

# %% [markdown]
# This dataset taken from kaggle https://www.kaggle.com/new-york-state/nys-residential-homes-energy-efficiency-projects. This dataset have 29 columns and 57924 rows of information. In this project, there are 3 steps that I will do, there are:
# 1. **Data Cleaning (Handle Missing Value and Outlier)**
# 2. **Exploratory Data Analysis**
# 3. **Modelling Machine Learning Algorithm to Make Classification for Homeowner to either get Green Jobs-Green NY Free or Not, based on Features that provide in this dataset**

# %% [markdown]
# ## Import Common Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read the information in Dataset

# %%
df =pd.read_csv('residential-existing-homes-one-to-four-units-energy-efficiency-projects-with-income-based-incentives-by-customer-type-beginning-2010.csv')
pd.set_option('display.max_columns',None)

# %%
df.head()
# Out:
#           Reporting Period Home Performance Project ID  \
# 0  2019-09-30T00:00:00.000                      112396
# 1  2019-09-30T00:00:00.000                      115545
# 2  2019-09-30T00:00:00.000                      115677
# 3  2019-09-30T00:00:00.000                      115949
# 4  2019-09-30T00:00:00.000                      116341
#
#   Home Performance Site ID Project County      Project City  Project Zip  \
# 0                    65558       Herkimer  Salisbury Center        13454
# 1                    67228         Oneida           Clinton        13323
# 2                    67286       Onondaga          Marietta        13110
# 3                    67427       Herkimer             Ilion        13357
# 4                    67625         Oneida            Vernon        13476
#
#      Gas Utility               Electric Utility  Project Completion Date  \
# 0  National Grid                  National Grid  2015-11-12T00:00:00.000
# 1  National Grid                  National Grid  2015-11-13T00:00:00.000
# 2            NaN  New York State Electric & Gas  2015-11-13T00:00:00.000
# 3  National Grid      Municipal (Not Qualified)  2015-11-13T00:00:00.000
# 4            NaN                  National Grid  2015-12-09T00:00:00.000
#
#   Customer Type Low-Rise or Home Performance Indicator  Total Project Cost  \
# 0        Market                       Home Performance                5235
# 1        Market                       Home Performance                4145
# 2        Market                       Home Performance                4310
# 3        Market                       Home Performance                3570
# 4        Market                       Home Performance                3785
#
#    Total Incentives Type of Program Financing  \
# 0               524                       NaN
# 1               415                       NaN
# 2               431                       NaN
# 3               357                       NaN
# 4               379                       NaN
#
#    Amount Financed Through Program Pre-Retrofit Home Heating Fuel Type  \
# 0                              0.0                         Natural Gas
# 1                              0.0                         Natural Gas
# 2                              0.0                            Kerosene
# 3                              0.0                         Natural Gas
# 4                              0.0                            Kerosene
#
#    Year Home Built  Size of Home  Volume of Home  Number of Units  \
# 0           1900.0        2160.0         25200.0              1.0
# 1           1900.0        1843.0             NaN              1.0
# 2           1975.0        1872.0         16016.0              1.0
# 3           1956.0        1972.0         30232.0              1.0
# 4           1976.0        1008.0         10272.0              1.0
#
#      Measure Type  Estimated Annual kWh Savings  \
# 0  Building Shell                           383
# 1  Building Shell                           138
# 2  Building Shell                            15
# 3  Building Shell                            22
# 4  Building Shell                             0
#
#    Estimated Annual MMBtu Savings  First Year Energy Savings $ Estimate  \
# 0                              49                                   556
# 1                              37                                   401
# 2                              24                                   748
# 3                               6                                    67
# 4                              11                                   324
#
#   Homeowner Received Green Jobs-Green NY Free/Reduced Cost Audit (Y/N)  \
# 0                                                  Y
# 1                                                  Y
# 2                                                  Y
# 3                                                  Y
# 4                                                  Y
#
#    Location  New York Zip Codes  Counties  NYS Municipal Boundaries
# 0       NaN                 NaN       NaN                       NaN
# 1       NaN                 NaN       NaN                       NaN
# 2       NaN                 NaN       NaN                       NaN
# 3       NaN                 NaN       NaN                       NaN
# 4       NaN                 NaN       NaN                       NaN

# %%
df.shape
# Out:
# (57924, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57924 entries, 0 to 57923
# Data columns (total 29 columns):
# Reporting Period                                                        57924 non-null object
# Home Performance Project ID                                             57924 non-null object
# Home Performance Site ID                                                57924 non-null object
# Project County                                                          57922 non-null object
# Project City                                                            57924 non-null object
# Project Zip                                                             57924 non-null int64
# Gas Utility                                                             41807 non-null object
# Electric Utility                                                        57924 non-null object
# Project Completion Date                                                 57924 non-null object
# Customer Type                                                           57924 non-null object
# Low-Rise or Home Performance Indicator                                  57924 non-null object
# Total Project Cost                                                      57924 non-null int64
# Total Incentives                                                        57924 non-null int64
# Type of Program Financing                                               17612 non-null object
# Amount Financed Through Program                                         57923 non-null float64
# Pre-Retrofit Home Heating Fuel Type                                     57879 non-null object
# Year Home Built                                                         40513 non-null float64
# Size of Home                                                            47618 non-null float64
# Volume of Home                                                          44500 non-null float64
# Number of Units                                                         40449 non-null float64
# Measure Type                                                            57924 non-null object
# Estimated Annual kWh Savings                                            57924 non-null int64
# Estimated Annual MMBtu Savings                                          57924 non-null int64
# First Year Energy Savings $ Estimate                                    57924 non-null int64
# Homeowner Received Green Jobs-Green NY Free/Reduced Cost Audit (Y/N)    57924 non-null object
# Location                                                                0 non-null float64
# New York Zip Codes                                                      0 non-null float64
# Counties                                                                0 non-null float64
# NYS Municipal Boundaries                                                0 non-null float64
# dtypes: float64(9), int64(6), object(14)
# memory usage: 12.8+ MB

# %%
df.describe()
# Out:
#         Project Zip  Total Project Cost  Total Incentives  \
# count  57924.000000        57924.000000      57924.000000
# mean   13326.607848         8358.717302       1607.861491
# std     1317.617997         5830.256778       1626.769811
# min    10001.000000            0.000000          0.000000
# 25%    12203.000000         4481.750000        379.000000
# 50%    13602.000000         6850.500000        939.000000
# 75%    14519.000000        10535.250000       2495.000000
# max    14905.000000        94772.000000      12000.000000
#
#        Amount Financed Through Program  Year Home Built  Size of Home  \
# count                     57923.000000     40513.000000  47618.000000
# mean                       2663.354332      1950.828203   1863.671427
# std                        5102.149329        36.980414    714.847283
# min                           0.000000      1800.000000    387.000000
# 25%                           0.000000      1930.000000   1320.000000
# 50%                           0.000000      1958.000000   1736.000000
# 75%                        3770.500000      1979.000000   2264.000000
# max                       25000.000000      2019.000000   5512.000000
#
#        Volume of Home  Number of Units  Estimated Annual kWh Savings  \
# count    44500.000000     40449.000000                  57924.000000
# mean     17196.000022         1.033672                    434.613096
# std       8768.241512         0.226231                   2014.245939
# min       1088.000000         1.000000                 -27585.000000
# 25%      11690.750000         1.000000                      0.000000
# 50%      15392.000000         1.000000                      7.000000
# 75%      20416.000000         1.000000                    353.000000
# max     334776.000000         4.000000                 174258.000000
#
#        Estimated Annual MMBtu Savings  First Year Energy Savings $ Estimate  \
# count                    57924.000000                          57924.000000
# mean                        29.215748                            625.605276
# std                         27.996649                            730.219993
# min                       -362.000000                              0.000000
# 25%                         12.000000                            174.000000
# 50%                         23.000000                            383.000000
# 75%                         39.000000                            783.000000
# max                        455.000000                          24396.000000
#
#        Location  New York Zip Codes  Counties  NYS Municipal Boundaries
# count       0.0                 0.0       0.0                       0.0
# mean        NaN                 NaN       NaN                       NaN
# std         NaN                 NaN       NaN                       NaN
# min         NaN                 NaN       NaN                       NaN
# 25%         NaN                 NaN       NaN                       NaN
# 50%         NaN                 NaN       NaN                       NaN
# 75%         NaN                 NaN       NaN                       NaN
# max         NaN                 NaN       NaN                       NaN

# %%
df.describe(exclude='number')
# Out:
#                Reporting Period Home Performance Project ID  \
# count                     57924                       57924
# unique                        1                       57924
# top     2019-09-30T00:00:00.000                P00001003969
# freq                      57924                           1
#
#        Home Performance Site ID Project County Project City  \
# count                     57924          57922        57924
# unique                    55975             62         1496
# top                      253993         Monroe    Rochester
# freq                          4          12637         7634
#
#                      Gas Utility Electric Utility  Project Completion Date  \
# count                      41807            57924                    57924
# unique                        14                8                     2389
# top     Rochester Gas & Electric    National Grid  2015-09-30T00:00:00.000
# freq                       13727            20705                     1535
#
#        Customer Type Low-Rise or Home Performance Indicator  \
# count          57924                                  57924
# unique             2                                      2
# top           Market                       Home Performance
# freq           34027                                  52838
#
#                       Type of Program Financing  \
# count                                     17612
# unique                                        4
# top     Green Jobs - Green NY Smart Energy Loan
# freq                                      13396
#
#        Pre-Retrofit Home Heating Fuel Type    Measure Type  \
# count                                57879           57924
# unique                                  12               3
# top                            Natural Gas  Building Shell
# freq                                 23080           57251
#
#        Homeowner Received Green Jobs-Green NY Free/Reduced Cost Audit (Y/N)
# count                                               57924
# unique                                                  2
# top                                                     Y
# freq                                                43894

# %%
listkolom=[]
for i in (df.columns):
    listkolom.append(i)
    
listtipe=[]
for i in (df.columns):
    listtipe.append(df[i].dtypes)
    
nullmany = df.isnull().sum().values

nullpctx = []
for i in nullmany:
    nullpctx.append(round(i/len(df),4)*100)
    
unik = df.nunique().values

samp = []
for i in df.columns:
    samp.append(df[i].sample().values)
    
pd.DataFrame({
    'dataFeatures' : listkolom,
    'dataType' : listtipe,
    'null' : nullmany,
    'nullpct' : nullpctx,
    'unique' : unik,
    'SampleValue' : samp
})
# Out:
#                                          dataFeatures dataType   null  \
# 0                                    Reporting Period   object      0
# 1                         Home Performance Project ID   object      0
# 2                            Home Performance Site ID   object      0
# 3                                      Project County   object      2
# 4                                        Project City   object      0
# 5                                         Project Zip    int64      0
# 6                                         Gas Utility   object  16117
# 7                                    Electric Utility   object      0
# 8                             Project Completion Date   object      0
# 9                                       Customer Type   object      0
# 10             Low-Rise or Home Performance Indicator   object      0
# 11                                 Total Project Cost    int64      0
# 12                                   Total Incentives    int64      0
# 13                          Type of Program Financing   object  40312
# 14                    Amount Financed Through Program  float64      1
# 15                Pre-Retrofit Home Heating Fuel Type   object     45
# 16                                    Year Home Built  float64  17411
# 17                                       Size of Home  float64  10306
# 18                                     Volume of Home  float64  13424
# 19                                    Number of Units  float64  17475
# 20                                       Measure Type   object      0
# 21                       Estimated Annual kWh Savings    int64      0
# 22                     Estimated Annual MMBtu Savings    int64      0
# 23               First Year Energy Savings $ Estimate    int64      0
# 24  Homeowner Received Green Jobs-Green NY Free/Re...   object      0
# 25                                           Location  float64  57924
# 26                                 New York Zip Codes  float64  57924
# 27                                           Counties  float64  57924
# 28                           NYS Municipal Boundaries  float64  57924
#
#     nullpct  unique                       SampleValue
# 0      0.00       1         [2019-09-30T00:00:00.000]
# 1      0.00   57924                    [P00000940005]
# 2      0.00   55975                    [S00000199229]
# 3      0.00      62                        [Onondaga]
# 4      0.00    1496                         [Geneseo]
# 5      0.00    1506                           [13601]
# 6     27.82      14  [National Fuel Gas Distribution]
# 7      0.00       8   [New York State Electric & Gas]
# 8      0.00    2389         [2018-06-01T00:00:00.000]
# 9      0.00       2                          [Market]
# 10     0.00       2                [Home Performance]
# 11     0.00   15990                            [6900]
# 12     0.00    4774                               [0]
# 13    69.59       4                             [nan]
# 14     0.00    9290                         [10308.0]
# 15     0.08      12                             [Oil]
# 16    30.06     217                          [1970.0]
# 17    17.79    2985                          [1200.0]
# 18    23.18   11506                         [10080.0]
# 19    30.17       4                             [1.0]
# 20     0.00       3                  [Building Shell]
# 21     0.00    4963                            [1718]
# 22     0.00     367                              [26]
# 23     0.00    3625                             [264]
# 24     0.00       2                               [Y]
# 25   100.00       0                             [nan]
# 26   100.00       0                             [nan]
# 27   100.00       0                             [nan]
# 28   100.00       0                             [nan]

# %% [markdown]
# ## Handling Missing Data

# %% [markdown]
# **See correlation between each numeric columns**

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),linewidth=0.5,annot=True)
plt.title('Correlation Between Numerical Columns',size=20)
plt.show()

# %% [markdown]
# **Drop the columns that will not be use**

# %%
df.drop(['Location', 'New York Zip Codes', 'Counties',
       'NYS Municipal Boundaries','Home Performance Project ID',
       'Home Performance Site ID','Reporting Period','Project Zip','Year Home Built','Type of Program Financing'],
        axis=1,inplace=True)

# %% [markdown]
# **Fill NaN Values in Project County Columns**

# %%
for i in range(len(df)):
    if str(df.loc[i,'Project County'])=='nan':
        if (df.loc[i,'Project City']) == 'Brewerton' :
            df.loc[i,'Project County'] = 'Onondaga'
        elif (df.loc[i,'Project City']) == 'Tonawanda' :
            df.loc[i,'Project County'] = 'Erie'

# %% [markdown]
# **Fill NaN Values in Amount Financed Through Program columns**

# %%
for i in range(len(df)):
    if str(df.loc[i,'Amount Financed Through Program'])=='nan':
        df.loc[i,'Amount Financed Through Program'] = 0.0

# %% [markdown]
# **Fill NaN Values in Gas Utility columns**

# %%
df['Gas Utility'].fillna('No Gas Provider',inplace=True)

# %% [markdown]
# **Fill NaN Values in Volume of Home columns and Size of Home colums**

# %%
# Fill Missing Value in Volume of Home based on Size of Home
meanVolume = df.groupby('Size of Home').mean()['Volume of Home']
def fillVolume(x):
    for i in df['Size of Home']:
        if x['Volume of Home'] > 0:
            return x['Volume of Home']
        else:
            if x['Size of Home'] > 0:
                return meanVolume.loc[x['Size of Home']]
            else:
                return np.nan
df['Volume of Home'] = df.apply(fillVolume,axis=1)

# %%
# Fill Missing Value in Size of Home based on Volume of Home
meanSize = df.groupby('Volume of Home').mean()['Size of Home']
def fillSize(x):
    for i in df['Volume of Home']:
        if x['Size of Home'] > 0:
            return x['Size of Home']
        else:
            if x['Volume of Home'] > 0:
                return meanSize.loc[x['Volume of Home']]
            else:
                return np.nan
df['Size of Home'] = df.apply(fillSize,axis=1)

# %%
nan_vol = df['Volume of Home'].isnull().sum()
nan_size = df['Size of Home'].isnull().sum()
print(f'Total NaN Values in Volume of Home column: {nan_vol} \n')
print(f'Total NaN Values in Size of Home column: {nan_size}')
# Out:
# Total NaN Values in Volume of Home column: 8725
#
# Total NaN Values in Size of Home column: 9929

# %% [markdown]
# > For Volume of Home column and Size of Home column, after the NaN Values filled using mean from groupby method, those columns still have some NaN Values. To handle the issue in those columns, the rest of missing data will fill by median of their values from city projects where the projects was did.

# %%
meanCity = df.groupby('Project City').median()[['Volume of Home','Size of Home']]
def fill_Vol(x):
    if (pd.isnull(x['Volume of Home']) == True):
        project_city = x['Project City']
        value = meanCity.loc[project_city][0]
        return value
    else:
        return x['Volume of Home']
df['Volume of Home'] = df.apply(fill_Vol, axis=1)

def fill_Size(x):
    if (pd.isnull(x['Size of Home']) == True):
        project_city = x['Project City']
        value = meanCity.loc[project_city][1]
        return value
    else:
        return x['Size of Home']
df['Size of Home'] = df.apply(fill_Size, axis=1)

# %%
nan_vol = df['Volume of Home'].isnull().sum()
nan_size = df['Size of Home'].isnull().sum()
print(f'Total NaN Values in Volume of Home column: {nan_vol} \n')
print(f'Total NaN Values in Size of Home column: {nan_size}')
# Out:
# Total NaN Values in Volume of Home column: 47
#
# Total NaN Values in Size of Home column: 71

# %% [markdown]
# > Looks like there are still missing value in Volume of Home and Size of Home columns, I choose to fill the rest of missing value in those columns by groupby with the county of the projects and take the median values for filling missing values

# %%
meanCounty = df.groupby('Project County').median()[['Volume of Home','Size of Home']]
def fill_Vol_County(x):
    if (pd.isnull(x['Volume of Home']) == True):
        project_county = x['Project County']
        value = meanCounty.loc[project_county][0]
        return value
    else:
        return x['Volume of Home']
df['Volume of Home'] = df.apply(fill_Vol_County, axis=1)

def fill_Size_County(x):
    if (pd.isnull(x['Size of Home']) == True):
        project_county = x['Project County']
        value = meanCounty.loc[project_county][1]
        return value
    else:
        return x['Size of Home']
df['Size of Home'] = df.apply(fill_Size_County, axis=1)

# %%
nan_vol = df['Volume of Home'].isnull().sum()
nan_size = df['Size of Home'].isnull().sum()
print(f'Total NaN Values in Volume of Home column: {nan_vol} \n')
print(f'Total NaN Values in Size of Home column: {nan_size}')
# Out:
# Total NaN Values in Volume of Home column: 0
#
# Total NaN Values in Size of Home column: 0

# %% [markdown]
# > Now the missing values in Volume of Home and Size of Home columns has been filled

# %% [markdown]
# **Fill NaN Values in Number of Units column**

# %%
Vol_AvgUnit4 = df[df['Number of Units']==4.0]['Volume of Home'].mean()
Vol_AvgUnit3 = df[df['Number of Units']==3.0]['Volume of Home'].mean()
Vol_AvgUnit2 = df[df['Number of Units']==2.0]['Volume of Home'].mean()
Vol_AvgUnit1 = df[df['Number of Units']==1.0]['Volume of Home'].mean()
print (f'Avg Volume for 4 Unit: {Vol_AvgUnit4}\n')
print (f'Avg Volume for 3 Unit: {Vol_AvgUnit3}\n')
print (f'Avg Volume for 2 Unit: {Vol_AvgUnit2}\n')
print (f'Avg Volume for 1 Unit: {Vol_AvgUnit1}')
for i in range(len(df)):
    if str(df.loc[i,'Number of Units'])=='nan':
        if df.loc[i,'Volume of Home'] >= Vol_AvgUnit4:
            df.loc[i,'Number of Units'] = 4.0
        elif df.loc[i,'Volume of Home'] >= Vol_AvgUnit3 and  df.loc[i,'Volume of Home'] < Vol_AvgUnit4:
            df.loc[i,'Number of Units'] = 3.0
        elif df.loc[i,'Volume of Home'] >= Vol_AvgUnit2 and  df.loc[i,'Volume of Home'] < Vol_AvgUnit3:
            df.loc[i,'Number of Units'] = 2.0
        elif df.loc[i,'Volume of Home'] < Vol_AvgUnit2:
            df.loc[i,'Number of Units'] = 1.0
# Out:
# Avg Volume for 4 Unit: 35578.97619047619
#
# Avg Volume for 3 Unit: 22390.9053935484
#
# Avg Volume for 2 Unit: 21269.82231104651
#
# Avg Volume for 1 Unit: 16196.952283895222

# %% [markdown]
# **Drop rows for NaN Values and change duplicate values in Pre-Retrofit Home Heating Fuel Type columns**

# %%
df.dropna(subset=['Pre-Retrofit Home Heating Fuel Type'],inplace=True)
df.loc[df[df['Pre-Retrofit Home Heating Fuel Type']=='Natural gas'].index,'Pre-Retrofit Home Heating Fuel Type'] = 'Natural Gas'
df.loc[df[df['Pre-Retrofit Home Heating Fuel Type']=='Electric'].index,'Pre-Retrofit Home Heating Fuel Type'] = 'Electricity'
df.loc[df[df['Pre-Retrofit Home Heating Fuel Type']=='Anthracite Coal'].index,'Pre-Retrofit Home Heating Fuel Type'] = 'Coal'
df.loc[df[df['Pre-Retrofit Home Heating Fuel Type']=='Bituminous Coal'].index,'Pre-Retrofit Home Heating Fuel Type'] = 'Coal'
df.reset_index(drop=True,inplace=True)

# %% [markdown]
# **Change type of some columns to make the data more understandable**

# %%
df['Project Completion Date'] = pd.to_datetime(df['Project Completion Date'],format= '%Y-%m-%d')

# %% [markdown]
# ## Drop Outlier

# %%
# See Outlier distribution use boxplot
plt.figure(figsize=(15,5))
sns.boxplot(data=df.select_dtypes(include='number'),orient='v')
plt.xticks(rotation=45)
plt.title('Outlier Data in Columns',size=20)
plt.show()

# %% [markdown]
# **Drop Multivariate Outlier use Mahalanobis Distance**

# %%
# Import library that needed
from mahalanobis import Mahalanobis
from scipy.stats import chi2
# Choose columns that we want to check the outlier by make a new dataframe
df_outlier = df.select_dtypes(include='number')
ppf_score = chi2.ppf((1-0.05),df=8)
# Create new column filled by Mahalanobis distance for each rows
df_outlier['mahala'] = Mahalanobis(np.array(df_outlier),len(df_outlier)).distances
# Function to create label for outlier / non outlier data
def nama_label(col):
    if col > ppf_score:
        return 'Outlier'
    else:
        return 'Non Outlier'
df_outlier['Label'] = df_outlier['mahala'].apply(nama_label)
# Drop multivariate outlier
idx_outlier = df_outlier[df_outlier['Label']=='Outlier'].index
df.drop(index=idx_outlier,inplace=True)
df.reset_index(drop=True,inplace=True)

# %% [markdown]
# ## Final check of the value in dataset

# %%
listkolom=[]
for i in (df.columns):
    listkolom.append(i)
    
listtipe=[]
for i in (df.columns):
    listtipe.append(df[i].dtypes)
    
nullmany = df.isnull().sum().values

nullpctx = []
for i in nullmany:
    nullpctx.append(round(i/len(df),4)*100)
    
unik = df.nunique().values

samp = []
for i in df.columns:
    samp.append(df[i].sample().values)
    
pd.DataFrame({
    'dataFeatures' : listkolom,
    'dataType' : listtipe,
    'null' : nullmany,
    'nullpct' : nullpctx,
    'unique' : unik,
    'SampleValue' : samp
})
# Out:
#                                          dataFeatures        dataType  null  \
# 0                                      Project County          object     0
# 1                                        Project City          object     0
# 2                                         Gas Utility          object     0
# 3                                    Electric Utility          object     0
# 4                             Project Completion Date  datetime64[ns]     0
# 5                                       Customer Type          object     0
# 6              Low-Rise or Home Performance Indicator          object     0
# 7                                  Total Project Cost           int64     0
# 8                                    Total Incentives           int64     0
# 9                     Amount Financed Through Program         float64     0
# 10                Pre-Retrofit Home Heating Fuel Type          object     0
# 11                                       Size of Home         float64     0
# 12                                     Volume of Home         float64     0
# 13                                    Number of Units         float64     0
# 14                                       Measure Type          object     0
# 15                       Estimated Annual kWh Savings           int64     0
# 16                     Estimated Annual MMBtu Savings           int64     0
# 17               First Year Energy Savings $ Estimate           int64     0
# 18  Homeowner Received Green Jobs-Green NY Free/Re...          object     0
#
#     nullpct  unique                      SampleValue
# 0       0.0      62                        [Ontario]
# 1       0.0    1496                        [Webster]
# 2       0.0      14       [Rochester Gas & Electric]
# 3       0.0       8  [New York State Electric & Gas]
# 4       0.0    2389  [2013-01-11T00:00:00.000000000]
# 5       0.0       2                         [Market]
# 6       0.0       2               [Home Performance]
# 7       0.0   15955                           [9796]
# 8       0.0    4772                           [1004]
# 9       0.0    9283                            [0.0]
# 10      0.0       8                    [Natural Gas]
# 11      0.0    3144                         [1496.0]
# 12      0.0   11751                        [16416.0]
# 13      0.0       4                            [1.0]
# 14      0.0       3                 [Building Shell]
# 15      0.0    4935                            [834]
# 16      0.0     349                             [40]
# 17      0.0    3599                           [2166]
# 18      0.0       2                              [Y]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57833 entries, 0 to 57832
# Data columns (total 19 columns):
# Project County                                                          57833 non-null object
# Project City                                                            57833 non-null object
# Gas Utility                                                             57833 non-null object
# Electric Utility                                                        57833 non-null object
# Project Completion Date                                                 57833 non-null datetime64[ns]
# Customer Type                                                           57833 non-null object
# Low-Rise or Home Performance Indicator                                  57833 non-null object
# Total Project Cost                                                      57833 non-null int64
# Total Incentives                                                        57833 non-null int64
# Amount Financed Through Program                                         57833 non-null float64
# Pre-Retrofit Home Heating Fuel Type                                     57833 non-null object
# Size of Home                                                            57833 non-null float64
# Volume of Home                                                          57833 non-null float64
# Number of Units                                                         57833 non-null float64
# Measure Type                                                            57833 non-null object
# Estimated Annual kWh Savings                                            57833 non-null int64
# Estimated Annual MMBtu Savings                                          57833 non-null int64
# First Year Energy Savings $ Estimate                                    57833 non-null int64
# Homeowner Received Green Jobs-Green NY Free/Reduced Cost Audit (Y/N)    57833 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(5), object(9)
# memory usage: 8.4+ MB

# %% [markdown]
# > Looks like all the data is clean. It is ready to do exploratory data analysis, and machine learning modelling.

# %% [markdown]
# **Save to CSV File**

# %%
df.to_csv('Clean_FinalProject.csv',index=False)

# %%
db = df.copy()
db.rename({
    'Homeowner Received Green Jobs-Green NY Free/Reduced Cost Audit (Y/N)' : 'Label',
}, axis = 1, inplace = True)
db.to_csv('Dataset_Dashboard.csv', index=False)
